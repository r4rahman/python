# %%
import pandas as pd
data = pd.read_csv('C:\\Users\\faiza\\Downloads\\AppleStore.csv', usecols =[1, 3], nrows = 5)
data
# Out:
#                                           track_name currency
# 0                                    PAC-MAN Premium      USD
# 1                          Evernote - stay organized      USD
# 2    WeatherBug - Local Weather, Radar, Maps, Alerts      USD
# 3  eBay: Best App to Buy, Sell, Save! Online Shop...      USD
# 4                                              Bible      USD

# %%
data.columns
# Out:
# Index(['id', 'track_name', 'size_bytes', 'currency', 'price',
#        'rating_count_tot', 'rating_count_ver', 'user_rating',
#        'user_rating_ver', 'ver', 'cont_rating', 'prime_genre',
#        'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic'],
#       dtype='object')

# %%
data.size
# Out:
# 115152

# %%
data.shape
# Out:
# (7197, 16)

# %%
data.head()
# Out:
#           id                                         track_name  size_bytes  \
# 0  281656475                                    PAC-MAN Premium   100788224
# 1  281796108                          Evernote - stay organized   158578688
# 2  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts   100524032
# 3  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...   128512000
# 4  282935706                                              Bible    92774400
#
#   currency  price  rating_count_tot  rating_count_ver  user_rating  \
# 0      USD   3.99             21292                26          4.0
# 1      USD   0.00            161065                26          4.0
# 2      USD   0.00            188583              2822          3.5
# 3      USD   0.00            262241               649          4.0
# 4      USD   0.00            985920              5320          4.5
#
#    user_rating_ver     ver cont_rating   prime_genre  sup_devices.num  \
# ...

# %%
data.track_name
# Out:
# 0                                         PAC-MAN Premium
# 1                               Evernote - stay organized
# 2         WeatherBug - Local Weather, Radar, Maps, Alerts
# 3       eBay: Best App to Buy, Sell, Save! Online Shop...
# 4                                                   Bible
# 5                                        Shanghai Mahjong
# 6                  PayPal - Send and request money safely
# 7                                 Pandora - Music & Radio
# 8                             PCalc - The Best Calculator
# 9                                             Ms. PAC-MAN
# 10                              Solitaire by MobilityWare
# 11                                       SCRABBLE Premium
# 12                   Google – Search made just for mobile
# 13                       Bank of America - Mobile Banking
# 14                                               FreeCell
# 15                 TripAdvisor Hotels Flights Restaurants
# ...

# %%
data.count_values(track_name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-4b84265bc357> in <module>
# ----> 1 data.count_values(track_name)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'count_values'

# %%
data
# Out:
#               id                                         track_name  \
# 0      281656475                                    PAC-MAN Premium
# 1      281796108                          Evernote - stay organized
# 2      281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3      282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4      282935706                                              Bible
# 5      283619399                                   Shanghai Mahjong
# 6      283646709             PayPal - Send and request money safely
# 7      284035177                            Pandora - Music & Radio
# 8      284666222                        PCalc - The Best Calculator
# 9      284736660                                        Ms. PAC-MAN
# 10     284791396                          Solitaire by MobilityWare
# 11     284815117                                   SCRABBLE Premium
# 12     284815942               Google – Search made just for mobile
# ...

# %%
data.track_name.count_values()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-3b47c4fff0cc> in <module>
# ----> 1 data.track_name and id.count_values()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1476         raise ValueError("The truth value of a {0} is ambiguous. "
#    1477                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1478                          .format(self.__class__.__name__))
#    1479
#    1480     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
def unique():
    rows = list(csv.reader(open('C:\\Users\\faiza\\Downloads\\AppleStore.csv','r'), delimiter=','))
    result = []
    for r in rows:
        key = r
        if key not in result:
            result.append(r)
    return result

# %%
data.track_name
# Out:
# 0                                         PAC-MAN Premium
# 1                               Evernote - stay organized
# 2         WeatherBug - Local Weather, Radar, Maps, Alerts
# 3       eBay: Best App to Buy, Sell, Save! Online Shop...
# 4                                                   Bible
# 5                                        Shanghai Mahjong
# 6                  PayPal - Send and request money safely
# 7                                 Pandora - Music & Radio
# 8                             PCalc - The Best Calculator
# 9                                             Ms. PAC-MAN
# 10                              Solitaire by MobilityWare
# 11                                       SCRABBLE Premium
# 12                   Google – Search made just for mobile
# 13                       Bank of America - Mobile Banking
# 14                                               FreeCell
# 15                 TripAdvisor Hotels Flights Restaurants
# ...

# %%
data.track_name.unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-3f8170d7e397> in <module>
# ----> 1 data.track_name.unique()
#
# NameError: name 'data' is not defined

# %%
rat = data.sort_values('rating_count_tot',ascending = False)
rat_data = rat[:10]
print(rat_data.track_name, rat_data.rating_count_tot)
# Out:
# 16                     Facebook
# 519                   Instagram
# 1346             Clash of Clans
# 707                  Temple Run
# 7       Pandora - Music & Radio
# 755                   Pinterest
# 4                         Bible
# 1493           Candy Crush Saga
# 178               Spotify Music
# 275                 Angry Birds
# Name: track_name, dtype: object 16      2974676
# 519     2161558
# 1346    2130805
# 707     1724546
# 7       1126879
# 755     1061624
# 4        985920
# 1493     961794
# 178      878563
# 275      824451
# Name: rating_count_tot, dtype: int64

# %%
data.head()
# Out:
#           id                                         track_name  size_bytes  \
# 0  281656475                                    PAC-MAN Premium   100788224
# 1  281796108                          Evernote - stay organized   158578688
# 2  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts   100524032
# 3  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...   128512000
# 4  282935706                                              Bible    92774400
#
#   currency  price  rating_count_tot  rating_count_ver  user_rating  \
# 0      USD   3.99             21292                26          4.0
# 1      USD   0.00            161065                26          4.0
# 2      USD   0.00            188583              2822          3.5
# 3      USD   0.00            262241               649          4.0
# 4      USD   0.00            985920              5320          4.5
#
#    user_rating_ver     ver cont_rating   prime_genre  sup_devices.num  \
# ...

# %%
n = data.cont_rating
n
# Out:
# 0        4+
# 1        4+
# 2        4+
# 3       12+
# 4        4+
# 5        4+
# 6        4+
# 7       12+
# 8        4+
# 9        4+
# 10       4+
# 11       4+
# 12      17+
# 13       4+
# 14       4+
# 15       4+
# 16       4+
# 17      12+
# 18      12+
# 19       4+
# 20       4+
# 21       4+
# 22       4+
# 23       4+
# 24       4+
# 25       4+
# 26       9+
# 27       4+
# 28       4+
# 29       4+
#        ...
# 7167     4+
# 7168     4+
# 7169     4+
# 7170     9+
# 7171     4+
# 7172     4+
# 7173     4+
# 7174     4+
# 7175     4+
# 7176     4+
# 7177     4+
# 7178     4+
# 7179     4+
# 7180     9+
# 7181     9+
# 7182     4+
# 7183     9+
# 7184     9+
# 7185     9+
# 7186     4+
# 7187     4+
# 7188    12+
# 7189     9+
# 7190     4+
# 7191    17+
# 7192     4+
# 7193     4+
# 7194     9+
# 7195    12+
# 7196     4+
# Name: cont_rating, Length: 7197, dtype: object

# %%
data[data.cont_rating == '17+']
# Out:
#               id                                         track_name  \
# 12     284815942               Google – Search made just for mobile
# 38     291430598                                      Hurricane Pro
# 70     299853944                                新浪新闻-阅读最新时事热门头条资讯视频
# 86     303849934                                     Beer Pong Game
# 92     305343404                                             Tumblr
# 94     305939712                            Match™ - #1 Dating App.
# 101    306628397                                      Phrase Party!
# 104    307184892  CBS Sports App - Sports Scores, News, Stats, W...
# 111    307764057                                           niconico
# 113    308111628                          iCab Mobile (Web Browser)
# 160    319881193  Grindr - Gay and same sex guys chat, meet and ...
# 177    324266640             Fantasy Football Manager - FFM for FPL
# 180    325462190        PGA Championship 2016 – Baltusrol Golf Club
# ...

# %%
data[data.cont_rating =='4+']
# Out:
#               id                                         track_name  \
# 0      281656475                                    PAC-MAN Premium
# 1      281796108                          Evernote - stay organized
# 2      281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 4      282935706                                              Bible
# 5      283619399                                   Shanghai Mahjong
# 6      283646709             PayPal - Send and request money safely
# 8      284666222                        PCalc - The Best Calculator
# 9      284736660                                        Ms. PAC-MAN
# 10     284791396                          Solitaire by MobilityWare
# 11     284815117                                   SCRABBLE Premium
# 13     284847138                   Bank of America - Mobile Banking
# 14     284862767                                           FreeCell
# 15     284876795             TripAdvisor Hotels Flights Restaurants
# ...

# %%
data[data.cont_rating == '9+']
# Out:
#               id                                   track_name  size_bytes  \
# 26     286911400                                     Hangman.     4765696
# 36     290807369                            Line Rider iRide™     1646592
# 39     292421271                                 Fieldrunners    66872320
# 46     293760823         iFart - The Original Fart Sounds App    60320768
# 78     301387274                                   Pocket God   145293312
# 83     303058767                                         MASH    41691136
# 129    311466554                          Pocket Tanks Deluxe    39827456
# 163    320300350                             Virtual Families    27746273
# 170    321756558               Pixel Starships™ : 8Bit MMORPG    69083136
# 171    322423174                                 Traffic Rush     8573952
# 183    325954996           Spider:  The Secret of Bryce Manor   126312448
# 190    326979430                       BATTLE BEARS: Zombies!   103197675
# ...

# %%
data[data.cont_rating == '12+']
# Out:
#               id                                         track_name  \
# 3      282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 7      284035177                            Pandora - Music & Radio
# 17     284910350     Yelp - Nearby Restaurants, Shopping & Services
# 18     284993459  Shazam - Discover music, artists, videos & lyrics
# 31     289084315                              Period Tracker Deluxe
# 33     289523017                          Blackjack by MobilityWare
# 35     290638154          iHeartRadio – Free Music & Radio Stations
# 41     292738169  Deezer - Listen to your Favorite Music & Playl...
# 55     295775656       12 Steps AA Companion - Alcoholics Anonymous
# 69     299515267                          Allrecipes Dinner Spinner
# 74     300255638            ABC News - US & World News + Live Video
# 90     304871622                                    Zombieville USA
# 100    306621789          HuffPost - News, Politics & Entertainment
# ...

# %%
import numpy as np
df = pd.DataFrame(df = pd.DataFrame(np.random.randn(5, 3), "columns=['column_1_name','column_2_name','column_3_name']))
df

# %%
import csv
import random

records=2000
print("Making %d records\n" % records)

fieldnames=['Roll_no','Name','Age','Marks','Result']
writer = csv.DictWriter(open("student.csv", "w"), fieldnames=fieldnames)

names=['Ankur', 'Sangeeta', 'Sujata', 'Anubhav', 'Sahil', 'Akshay','Monika','Ajeet','Rahman']
#result=['Distinction', 'First', 'Second', 'Third','Fail']

writer.writerow(dict(zip(fieldnames, fieldnames)))
for i in range(0, records):
  writer.writerow(dict([
    ('Roll_no', i),
    ('Name', random.choice(names)),
    ('Age', str(random.randint(20,25))),
    ('Marks',str(random.randint(20,100)))]))
# Out:
# Making 2000 records

# %%
# with open('student.csv','a') as fd:
for i in(0, records):
    if Marks>=75:
        fd.Result.write('Distinction')
    elif Marks>=60 and Marks<75:
        fd.Result.write('First')
    elif Marks>=45 and Marks<60:
        fd.Result.write('Second')
    elif Marks>=30 and Marks<45:
        fd.Result.write('Third')
    else:
        fd.Result.write('Fail')
   # fd.write(myCsvRow)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-8f03d1d0c16b> in <module>
#       1 # with open('student.csv','a') as fd:
#       2 for i in(0, records):
# ----> 3     if Marks>=75:
#       4         fd.Result.write('Distinction')
#       5     elif Marks>=60 and Marks<75:
#
# NameError: name 'Marks' is not defined

# %%
import matplotlib.pyplot as plt
# rating = [66, 55, 44, 50]
plt.pie(i,labels = result, autopct= '%1.1f%%',explode = [0,0,0,.2], shadow = True,
        startangle = 90, labeldistance = 1.2)
